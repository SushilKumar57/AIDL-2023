# %%
# !python -m pip install matplotlib
# !python -m pip install opencv-python 
# !python -m pip install scikit-image
# !python -m pip install pillow
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\lenovo\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\lenovo\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\lenovo\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\lenovo\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# Image Processing and Computer Vision

# %%
import cv2
import skimage
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.8.0'

# %%
# Open/Show/Save an Image
img1 = plt.imread('download (1).jpeg')
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
img2 = cv2.imread('download (1).jpeg')
cv2.imshow('Image', img2)
cv2.waitKey(0)

#cv2.waitKey(1)
#cv2.destroyAllWindows()
#cv2.destroyAllWindows()
# Out:
# -1

# %%
img3 = skimage.io.imread("images (1).jpeg")
cv2.imshow(img3)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 2
#       1 img3 = skimage.io.imread("images (1).jpeg")
# ----> 2 cv2.imshow(img3)
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)

# %%
import numpy as np
r1 = np.random.randint(0,255,(500,500,3))

# %%
r2 = np.random.randint(0,255,(50,50))
plt.imshow(r2, cmap='gray')
# skimage.io.imshow(r2, cmap = 'gray')

# %%
img = np.ones((50,50,3), dtype='uint8') * 255
img[:25,:25,1:]  = 0 #= img[:25,:25,1:] * 0
img[:25,25:,::2] = 0 #= img[:25,25:,::2] * 0
img[25:,:25,:2] = 0 #= img[:25,25:,::2] * 0
img[25:,25:,2:]= 0 # = img[:25,25:,::2] * 0
plt.imshow(img)

# %%
# Image Type Conversion
  # Color Image to Grayscale
  # to Binary
# Geometric Transformaations
  # Cropping
  # Scaling
  # Rotation
# Image Arithmetic / Brightness, Contrast Adjustments
  # Addition
  # Subtraction
  # Multiplication
  # Division
  # Brightness & Contrast Adjustment
  # Filteration
# Morphology
  # Structuring Element
  # Region Properties
# Feature Detection
  # Feature Extraction
  # Feature Matching

# %%
img.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 img.shape
#
# NameError: name 'img' is not defined

# %%
img_large = cv2.resize(
    img, (1500,1500), interpolation=cv2.INTER_CUBIC)

img_small = cv2.resize(
    img, (0,0), fx=0.25,fy=0.25, interpolation=cv2.INTER_CUBIC)
img_small.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 img_large = cv2.resize(
#       2     img, (1500,1500), interpolation=cv2.INTER_CUBIC)
#       4 img_small = cv2.resize(
#       5     img, (0,0), fx=0.25,fy=0.25, interpolation=cv2.INTER_CUBIC)
#       6 img_small.shape
#
# NameError: name 'cv2' is not defined

# %%
img_x = cv2.warpAffine(img,  )
plt.imshow(img_x[:,:,::-1])
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 img_x = cv2.warpAffine(img,  )
#       2 plt.imshow(img_x[:,:,::-1])
#       3 import matplotlib.pyplot as plt
#
# NameError: name 'cv2' is not defined

# %%
import matplotlib.pyplot as plt
plt.subplot(1,3,1)
plt.title('Original')
plt.imshow(img[:,:,::-1]); plt.axis('off')

plt.subplot(1,3,2)
plt.title('Brightened')
plt.imshow(cv2.add(img[:,:,::-1], 20)); plt.axis('off')

plt.subplot(1,3,3)
plt.title('Darkened')
plt.imshow(cv2.subtract(img[:,:,::-1], 20)); plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 plt.subplot(1,3,1)
#       3 plt.title('Original')
# ----> 4 plt.imshow(img[:,:,::-1]); plt.axis('off')
#       6 plt.subplot(1,3,2)
#       7 plt.title('Brightened')
#
# NameError: name 'img' is not defined

# %%
plt.subplot(1,2,1)
